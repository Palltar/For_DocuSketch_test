# %%
from main1 import DrawingPlots
drowplots=DrawingPlots()
drowplots.draw_plots("https://ai-process-sandy.s3.eu-west-1.amazonaws.com/purge/deviation.json")

from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\plotting\_matplotlib\core.py:337: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = self.plt.figure(figsize=self.figsize)
# ['Графики/plots_0.png',
#  'Графики/plots_1.png',
#  'Графики/plots_2.png',
#  'Графики/plots_3.png',
#  'Графики/plots_4.png',
#  'Графики/plots_5.png',
#  'Графики/plots_6.png',
#  'Графики/plots_7.png',
#  'Графики/plots_8.png',
#  'Графики/plots_9.png',
#  'Графики/plots_10.png',
#  'Графики/plots_11.png',
#  'Графики/plots_12.png',
#  'Графики/plots_13.png',
#  'Графики/plots_14.png',
#  'Графики/plots_15.png',
#  'Графики/plots_16.png',
#  'Графики/plots_17.png',
#  'Графики/plots_18.png',
#  'Графики/plots_19.png',
#  'Графики/plots_20.png',
#  'Графики/plots_21.png',
#  'Графики/plots_22.png',
#  'Графики/plots_23.png',
#  'Графики/plots_24.png',
#  'Графики/plots_25.png',
#  'Графики/plots_last.png']

# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>
